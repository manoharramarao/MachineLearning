# %% [markdown]
# # Problem statement
#
# Predict purchase amount based on page speed

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(2)
page_speeds = np.random.normal(3.0, 1.0, 1000)
purchase_amount = np.random.normal(50.0, 10.0, 1000)/page_speeds

plt.scatter(page_speeds, purchase_amount)
plt.show()

# %%
# prepare data
x = np.array(page_speeds)
y = np.array(purchase_amount)

p4 = np.poly1d(np.polyfit(x, y, 4))

# %%
xp = np.linspace(0, 7, 100)

plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, p4(x))
print(r2)
# Out:
# 0.82937663963

# %% [markdown]
# # APIs
#
# 1. np.poly1d(np.polyfit(x, y, 4)) # this is the model
