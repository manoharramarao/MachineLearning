# %% [markdown]
# # problem statement
#
# Predict price of car based on multiple attributes of car like mileage, number of doors, cylinders etc.

# %%
import pandas as pd

df = pd.read_excel('../datasets/002_multiple_linear_regression/cars.xls')
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %%
# Prepare x and y
x = df[['Mileage', 'Cylinder', 'Doors']]
y = df[['Price']]
print(x)
print(y)
# Out:
#      Mileage  Cylinder  Doors
# 0       8221         6      4
# 1       9135         6      4
# 2      13196         6      4
# 3      16342         6      4
# 4      19832         6      4
# 5      22236         6      4
# 6      22576         6      4
# 7      22964         6      4
# 8      24021         6      4
# 9      27325         6      4
# 10     10237         6      4
# 11     15066         6      4
# 12     16633         6      4
# 13     19800         6      4
# 14     23359         6      4
# 15     23765         6      4
# 16     24008         6      4
# 17     26034         6      4
# 18     32896         6      4
# 19     34665         6      4
# 20      8970         6      4
# 21     10577         6      4
# 22     14363         6      4
# 23     16508         6      4
# 24     18908         6      4
# 25     19467         6      4
# 26     21394         6      4
# 27     22596         6      4
# 28     24469         6      4
# 29     25245         6      4
# ...

# %%
# scale values to stay between -1 and 1

import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

x[['Mileage', 'Cylinder', 'Doors']] = scale.fit_transform(x[['Mileage', 'Cylinder', 'Doors']].as_matrix())
print(x)
# Out:
#       Mileage  Cylinder     Doors
# 0   -1.417485  0.527410  0.556279
# 1   -1.305902  0.527410  0.556279
# 2   -0.810128  0.527410  0.556279
# 3   -0.426058  0.527410  0.556279
# 4    0.000008  0.527410  0.556279
# 5    0.293493  0.527410  0.556279
# 6    0.335001  0.527410  0.556279
# 7    0.382369  0.527410  0.556279
# 8    0.511409  0.527410  0.556279
# 9    0.914768  0.527410  0.556279
# 10  -1.171368  0.527410  0.556279
# 11  -0.581834  0.527410  0.556279
# 12  -0.390532  0.527410  0.556279
# 13  -0.003899  0.527410  0.556279
# 14   0.430591  0.527410  0.556279
# 15   0.480156  0.527410  0.556279
# 16   0.509822  0.527410  0.556279
# 17   0.757160  0.527410  0.556279
# 18   1.594886  0.527410  0.556279
# 19   1.810849  0.527410  0.556279
# 20  -1.326046  0.527410  0.556279
# 21  -1.129860  0.527410  0.556279
# 22  -0.667658  0.527410  0.556279
# 23  -0.405792  0.527410  0.556279
# 24  -0.112796  0.527410  0.556279
# 25  -0.044552  0.527410  0.556279
# ...

# %%
# split data to train and test frames

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
print(len(x_train))
print(len(y_train))
print(len(x_test))
print(len(y_test))
# Out:
# 643
# 643
# 161
# 161

# %%
# train the model
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# test your model by predicting prices for x_test and comparing with y_test
y_predict = regressor.predict(x_test)
print(y_test)
print(y_predict)
# Out:
#             Price
# 8    14862.093870
# 575  16256.236168
# 616  15802.652861
# 142  45061.951935
# 236  12425.389171
# 664  25618.281885
# 608  15174.346613
# 739  26012.374625
# 710  33005.779958
# 150  70755.466717
# 758  13811.155022
# 466  20839.149965
# 14   19774.249066
# 691  32746.131387
# 741  25959.122030
# 576  15724.252170
# 667  24852.495281
# 504  22004.930438
# 465  20676.165511
# 626  14398.922693
# 204  10354.043852
# 293  13106.900424
# 517  19204.809341
# 55   21562.047578
# 27   20406.099503
# 499  17768.059505
# 726  26698.078151
# 457  16345.943747
# 490  19682.035011
# 162  11472.022761
# ..            ...
# 800  16175.957604
# 250  15053.933735
# 662  27284.751328
# 239  12234.888053
# 654  30731.941655
# 351  39713.667922
# 695  29844.204004
# 2    16218.847862
# 796  17322.078404
# 344  41371.379273
# 156  60567.549093
# 535  15595.884133
# 752  13991.040057
# 742  23274.480711
# 402  17458.221529
# 612  15977.911084
# 403  17158.921998
# 727  27241.436178
# ...

# %%
# find summary

est = sm.OLS(y_train, x_train).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     14.52
# Date:                Sat, 23 Sep 2017   Prob (F-statistic):           3.69e-09
# Time:                        18:43:13   Log-Likelihood:                -7362.8
# No. Observations:                 643   AIC:                         1.473e+04
# Df Residuals:                     640   BIC:                         1.475e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mileage     -518.1991    876.341     -0.591      0.555   -2239.049    1202.651
# ...
